# %%
import pandas as pd
danawa_data = pd.read_excel('./2_danawa_data_final.xlsx')
danawa_data.head()
# 핸디스틱 청소기로 카테고리 제한
# 현재 인기순 정렬
# Out:
#       카테고리   회사명                      제품       가격  사용시간  흡입력
# 0  핸디스틱청소기  LG전자   오브제컬렉션 코드제로 A9S AX958  1089950  30.0  280
# 1  핸디스틱청소기   샤오미                  미홀 M22   149000  50.0    0
# 2  핸디스틱청소기  삼성전자      비스포크 제트 VS20B956AX   433240  60.0  220
# 3  핸디스틱청소기  LG전자  오브제컬렉션 코드제로 A9S AX9674   787860  30.0  250
# 4  핸디스틱청소기  삼성전자   비스포크 제트 AI VS25C970DW   716800  60.0  250

# %%
top_list = danawa_data.sort_values(["흡입력"], ascending = False)
top_list.head()
# Out:
#         카테고리    회사명           제품      가격  사용시간  흡입력
# 145  핸디스틱청소기    비브르     스톰파워 V50  258000  50.0  450
# 56   핸디스틱청소기    아이룸      윈드포스 F9  178000  40.0  420
# 345  핸디스틱청소기    비브르  V38 스페셜 에디션  195000  50.0  410
# 75   핸디스틱청소기    아이룸      플래티넘 S9  198000  45.0  410
# 51   핸디스틱청소기  DIBEA          원스텝  349000  50.0  400

# %%
top_list = danawa_data.sort_values(["사용시간"], ascending = False)
top_list.head()
# Out:
#         카테고리   회사명                     제품       가격   사용시간  흡입력
# 344  핸디스틱청소기   NaN                 LT-124    40370  240.0   80
# 262  핸디스틱청소기   샤오미              이지에 YE-01    29500  120.0    0
# 270  핸디스틱청소기  삼성전자  비스포크 제트 AI VS28C973IS  1260930  100.0  280
# 23   핸디스틱청소기   드리미                    V11   187430   90.0  250
# 224  핸디스틱청소기   드리미                    V12   388180   90.0  270

# %%
top_list = danawa_data.sort_values(["사용시간", "흡입력"], ascending = False)
top_list.head()
# Out:
#         카테고리   회사명                     제품       가격   사용시간  흡입력
# 344  핸디스틱청소기   NaN                 LT-124    40370  240.0   80
# 262  핸디스틱청소기   샤오미              이지에 YE-01    29500  120.0    0
# 270  핸디스틱청소기  삼성전자  비스포크 제트 AI VS28C973IS  1260930  100.0  280
# 224  핸디스틱청소기   드리미                    V12   388180   90.0  270
# 23   핸디스틱청소기   드리미                    V11   187430   90.0  250

# %%
price_mean_value = danawa_data['가격'].mean()
suction_mean_value = danawa_data['흡입력'].mean()
use_time_mean_value = danawa_data['사용시간'].mean()
print('가격 평균', price_mean_value)
print('흡입력 평균', suction_mean_value)
print('사용시간 평균', use_time_mean_value)
# Out:
# 가격 평균 393895.6912181303
# 흡입력 평균 136.10198300283287
# 사용시간 평균 44.66566265060241

# %%
condition_data = danawa_data[
    (danawa_data['가격'] <= price_mean_value) &
    (danawa_data['흡입력'] >= suction_mean_value) &
    (danawa_data['사용시간'] >= use_time_mean_value)]
condition_data
# Out:
#         카테고리       회사명                    제품      가격  사용시간  흡입력
# 23   핸디스틱청소기       드리미                   V11  187430  90.0  250
# 25   핸디스틱청소기     DIBEA      ALLNEW29000 PLUS  248000  50.0  400
# 33   핸디스틱청소기      LG전자        코드제로 A9 A912PM  243970  50.0  160
# 35   핸디스틱청소기       아이닉               i20 엘리트  157990  50.0  180
# 38   핸디스틱청소기       아이닉        NEW i20 (23년형)  197990  50.0  350
# 44   핸디스틱청소기       아이닉              i30 아이타워  268990  50.0  350
# 45   핸디스틱청소기       드리미                   V10  154670  60.0  220
# 51   핸디스틱청소기     DIBEA                   원스텝  349000  50.0  400
# 63   핸디스틱청소기  대우어플라이언스            DEX-EV7000  134000  50.0  250
# 75   핸디스틱청소기       아이룸               플래티넘 S9  198000  45.0  410
# 82   핸디스틱청소기       드리미                  V10S  151820  60.0  140
# 94   핸디스틱청소기      JONR              ED20 PRO  255830  60.0  170
# 114  핸디스틱청소기       아이닉        NEW i20 (21년형)  199000  50.0  300
# 116  핸디스틱청소기       샤오미               미지아 K10  194000  65.0  150
# 123  핸디스틱청소기       샤오미          디어마 DEM-T30W  105790  45.0  230
# 130  핸디스틱청소기     DIBEA               THE NEW  179000  50.0  390
# 132  핸디스틱청소기     DIBEA          ALLNEW22000+  199000  50.0  390
# 135  핸디스틱청소기     DIBEA               올인원 컴팩트  139000  50.0  230
# 140  핸디스틱청소기      로이드미            S1 Special   69000  50.0  200
# 141  핸디스틱청소기       캐치웰                  HC10  159000  50.0  300
# 144  핸디스틱청소기     DIBEA           ALLNEW29000  249000  48.0  390
# 145  핸디스틱청소기       비브르              스톰파워 V50  258000  50.0  450
# 156  핸디스틱청소기       에어르                    V3  298000  55.0  350
# 169  핸디스틱청소기      로이드미                X30 프로  156000  70.0  265
# 171  핸디스틱청소기       캐치웰  에이센스 VC234 MJ35-7S20  158860  50.0  350
# 188  핸디스틱청소기      JONR              VC10 PRO  177106  60.0  270
# 198  핸디스틱청소기       샤오미                   G10  328860  65.0  250
# 205  핸디스틱청소기       샤오미           COCLEAN V30  114430  60.0  250
# 210  핸디스틱청소기       퍼피유         T12 Pro Rinse  355510  70.0  260
# 224  핸디스틱청소기       드리미                   V12  388180  90.0  270
# 225  핸디스틱청소기     에어메이드        스마트포스 AMC-3500  199000  45.0  370
# 229  핸디스틱청소기     DIBEA                  올인원뉴  169000  50.0  200
# 232  핸디스틱청소기     DIBEA            TSX-25000A  168620  45.0  250
# 257  핸디스틱청소기    에버튼하우스           EHMC-DC231A  123670  47.0  260
# 288  핸디스틱청소기      JONR                  VC10  117540  60.0  270
# 329  핸디스틱청소기       델로라           V11 파워 300W   79000  70.0  220
# 336  핸디스틱청소기       드리미                    V9  264230  60.0  200
# 338  핸디스틱청소기       드리미                   T20  299000  70.0  250
# 345  핸디스틱청소기       비브르           V38 스페셜 에디션  195000  50.0  410

# %%
from matplotlib import font_manager, rc
import matplotlib.pyplot as plt
import seaborn as sns
import platform

# %%
font_path = ''
if platform.system() == 'Windows': 
    font_path = 'c:/Windows/Fonts/malgun.ttf'
    font_name = font_manager.FontProperties(fname = font_path).get_name()
    rc('font', family = font_name)
elif platform.system() == 'Darwin':
    font_path = '/Users/$USER/Library/Fonts/AppleGothic.ttf'
    rc('font', family = 'AppleGothic')
else: 
    print('Check your OS system')
    
# %matplotlib inline

# %%
chart_data = danawa_data.dropna(axis = 0)
len(chart_data)
# Out:
# 331

# %%
suction_max_value = chart_data['흡입력'].max()
suction_min_value = chart_data['흡입력'].min()
use_time_max_value = chart_data['사용시간'].max()
use_time_min_value = chart_data['사용시간'].min()
print(suction_max_value)
print(suction_min_value)
# Out:
# 450
# 0

# %%
plt.figure(figsize=(20,10))
plt.title("무선 핸디스틱청소기 차트")
sns.scatterplot(x ='흡입력', y = '사용시간', size='가격', hue=chart_data['회사명'],
            data=chart_data, sizes=(10, 1000),legend=False)
plt.plot([0, suction_max_value], [use_time_mean_value, use_time_mean_value],
         'r--', lw=1)
plt.plot([suction_mean_value, suction_mean_value], [use_time_min_value, use_time_max_value],
         'r--', lw=1)
plt.show()

# %%
chart_data_selected = chart_data[:25]
len(chart_data_selected)
# Out:
# 25

# %%
suction_max_value = chart_data_selected['흡입력'].max()
suction_mean_value = chart_data_selected['흡입력'].mean()
use_time_max_value = chart_data_selected['사용시간'].max()
use_time_mean_value = chart_data_selected['사용시간'].mean()
plt.figure(figsize=(20, 10))
plt.title("무선 핸디스틱청소기 TOP 20")
sns.scatterplot(x='흡입력', y='사용시간',
                size='가격', hue=chart_data_selected['회사명'],
                data=chart_data_selected, sizes=(100, 2000),
                legend=False)
plt.plot([0, suction_max_value], [use_time_mean_value, use_time_mean_value],
         'r--', lw=1)
plt.plot([suction_mean_value, suction_mean_value], [0, use_time_max_value],
         'r--', lw=1)

dict_xy = dict()
for index, row in chart_data_selected.iterrows():
    x = row['흡입력']
    y = row['사용시간']
    s = row['제품']
    #s = row['제품'].split(" ")[0]
    try:
        dict_xy[(x, y)] += 1
    except:
        dict_xy[(x,y)] = 1
    plt.text(x, y+3*dict_xy[(x, y)], s, size=12)

#plt.show()
plt.savefig('top20.png')
